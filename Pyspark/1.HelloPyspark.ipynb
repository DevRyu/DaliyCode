# %%
# %python

value = 'Spark'
print("hello world \nThis! is %s Notebook!" % value)
print("hello world \nThis! is {} Notebook!".format(value))

# f-string does not support
# print(f"hello world \nThis! is {value} Notebook!")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansicyan">  File </span><span class="ansigreen">&quot;&lt;command-3597878636694599&gt;&quot;</span><span class="ansicyan">, line </span><span class="ansigreen">6</span>
# <span class="ansiyellow">    a = f&quot;hello world \nThis! is {value} Notebook!&quot;</span>
# <span class="ansigrey">                                                  ^</span>
# <span class="ansired">SyntaxError</span><span class="ansired">:</span> invalid syntax
# </div>
